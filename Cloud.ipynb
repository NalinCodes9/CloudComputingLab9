# %% [markdown]
# <a href="https://colab.research.google.com/github/NalinCodes9/CloudComputingLab9/blob/main/Cloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# %%
random.random()
# Out:
# 0.624832178094635

# %%
random.choice([1,3,5,7,8,9,11])
# Out:
# 5

# %%
random.uniform(1,30)
# Out:
# 13.092731503927991

# %%
random.seed(5)
print(random.randint(1,10))
# Out:
# 10

# %%
fruits='apple','mango','guava'
print(random.choice(fruits))
# Out:
# guava

# %%
row=5
column=5
matrix=[]
for i in range(row):
  row=[]
  for j in range(column):
    row.append(random.randint(1,10))
  matrix.append(row)
for row in matrix:
  print(row)
# Out:
# [5, 6, 9, 1, 8]
# [4, 1, 3, 2, 6]
# [8, 4, 7, 9, 2]
# [10, 4, 1, 4, 7]
# [5, 3, 7, 3, 2]

# %%
rows=10000
columns=10000

with open("data_file.txt",'w') as file:
  for i in range(rows):
    row=[]
    for j in range(columns):
      row.append(random.randit(1,20))
  file.write(" ".join(map(str,row))+'\n')
  print("Data file created succesfully")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_877/2827115983.py in <cell line: 0>()
#       6     row=[]
#       7     for j in range(columns):
# ----> 8       row.append(random.randit(1,20))
#       9   file.write(" ".join(map(str,row))+'\n')
#      10   print("Data file created succesfully")
#
# AttributeError: module 'random' has no attribute 'randit'
